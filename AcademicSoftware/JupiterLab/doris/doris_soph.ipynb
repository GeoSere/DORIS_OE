# %% [markdown]
# # DORIS Range-Rate Observation Equation (Simplistic Approach)
#
# We can formulate range-rate observation equations using the Doppler count data extracted from the DORIS RINEX files. A simplistic approach (disregarding all errors) would be to use the simple equation:
#
# $$ \frac{\phi (t_2) - \phi (t_1)}{\Delta t} \cdot \frac{c}{f} = \frac{\rho (t_2) - \rho (t_1)}{\Delta t} $$ in [m/sec], where $\rho (t)$ is the beacon-to-satellite distance.

# %%
# import dsoclasses
import datetime
import attotime
import numpy as np
from dsoclasses.doris.algorithms import beacon_nominal_frequency
from dsoclasses.rinex.doris.rinex import DorisRinex
from dsoclasses.time.pyattotime import at2pt, fsec2asec
from dsoclasses.orbits import sp3c, interpolator
from dsoclasses.geodesy import transformations
from dsoclasses.gnss import systems as gs
from dsoclasses.gnss import algorithms as alg
from dsoclasses.troposphere import gmf, gpt3, tropo
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import numpy as np
import math

# %% [markdown]
# We will need onr DORIS RINEX file and a corresponding sp3.

# %%
drinex = "/home/geosere/Desktop/data/s6arx24001.001"
dsp3 = "/home/geosere/Desktop/data/ssas6a20.b23357.e24001.DG_.sp3.001"

# %% [markdown]
# We will also need a meteorological data GPT3 file (Global Pressure Temperature File)

# %%
gpt3_file = "/home/geosere/Desktop/data/gpt3_5.grd"

# %% [markdown]
# We will also need an interpolator to compute satellite state at any observation epoch.

# %%
sp3 = sp3c.Sp3(dsp3)
satid = sp3.sat_ids[0]
sp3_data = sp3.get_satellite(satid, True)
intrp = interpolator.OrbitInterpolator(satid, sp3_data, 1800, 12, 'CubicSpline')

# %% [markdown]
# Intitialize the `DorisRinex` instance and select a beacon (Dionysos/DIOB).
# The following block calculates the residuals accounting for:
#     1) Ionospheric correction (uses ionospheric corrected L3 band + phase).
#     2) Uses a smoothed frequency offset data set to correct the frequency error.
#     3) Accounts for the correction of abberation error.

# %%
rnx = DorisRinex(drinex)

# DIOB DORIS beacon
diob = 'D31'

# approx. DIOB coordinats, see https://ids-doris.org/network/sitelogs/station.html?code=DIONYSOS
diob_xyz=np.array([4595212.468, 2039473.691, 3912617.891])

# %%
lat, lon, hgt = transformations.car2ell(*diob_xyz)
Rt = transformations.geodetic2lvlh(lat, lon)
R = Rt.transpose()
print(f"[DEBUG] DIOB φ: {np.degrees(lat):.6f}°, λ: {np.degrees(lon):.6f}°, h: {hgt:.2f} m")

def azele(rsat, rsta):
    enu = R @ (rsat - rsta)
    r  = np.linalg.norm(enu)
    az = np.arctan2(enu[0], enu[1])
    el = np.arcsin(enu[2] / r)
    return r, az, el
# Out:
# [DEBUG] DIOB φ: 38.078445°, λ: 23.932882°, h: 512.79 m

# %%
# initially, no previous phase observation ...
t1=None
satx_prev = None 
saty_prev = None 
satz_prev = None

# store results here 
t = []; res2=[]; t_all = []; F_all = []; raw_obs = [];

k_diob = 32    #shift factor for DIOB beacon
feN2, feN4 = beacon_nominal_frequency(k_diob)
print(f"feN2 (2 GHz channel) = {feN2:.9f} Hz")
print(f"feN4 (400 MHz channel) = {feN4:.9f} Hz")

frN = ((feN2**2 - feN4**2) / (feN2 - feN4))
sf = (feN2 / feN4)**2
feN_L3 = (sf * feN2 - math.sqrt(sf) * feN4) / (sf - 1)


# for every block in the RINEX file
for block in rnx:
    # for every beacon in the block
    for beacon, data in block:
            # use the block, RINEX provided clock correction to get to (approximate) TAI
            # date TAI = epoch + receiver clock offset
            t2 = block.t() + attotime.attotimedelta(nanoseconds=block.clock_offset()*1e9)
            t_all.append(at2pt(t2))
            #get frequency offset from block
            F = data['F']['value']
            F_all.append(F)

t0 = t_all[0]
t_seconds = [(ti - t0).total_seconds() for ti in t_all]

smoothing_coeffs = np.polyfit(t_seconds, F_all, 4)
F_smooth_fn = np.poly1d(smoothing_coeffs)

# for every block in the RINEX file
for block in rnx:
    # for every beacon in the block
    for beacon, data in block:
        # match DIOB
        if beacon == diob:
            # use the block, RINEX provided clock correction to get to (approximate) TAI
            # date TAI = epoch + receiver clock offset
            t2 = block.t() + attotime.attotimedelta(nanoseconds=block.clock_offset()*1e9)
            # satellite position at the current epoch (taking into account signal travel time)
            satx, saty, satz, _, _ = alg.sat_at_emission_time(diob_xyz, t2, intrp, None)
            rsat2 = np.array([satx, saty, satz])
            # tropospheric delay
            r2 = np.linalg.norm(np.array([satx, saty, satz])-np.array(diob_xyz))
            _, _, el = azele(np.array((satx, saty, satz)), np.array(diob_xyz))
            dT = tropo.tropo_delay(np.array(diob_xyz), t2, el, gpt3_file)
            
            # L1 and L2 measurements
            L2_1 = data['L1']['value']
            L2_2 = data['L2']['value']
            #L3 build
            L3 = (sf*L2_1 - math.sqrt(sf)*L2_2)/(sf-1)
            
            # --- Λειασμένη συχνότητα F
            t2_sec = (at2pt(t2) - t0).total_seconds()
            F_smoothed = F_smooth_fn(t2_sec)
            #print(f"{frT:.3f} {frN:.3f}")
            # --- frT με βάση την λειασμένη F
            frT = frN * (1 + F_smoothed * 1e-11)
            
            # beacon-to-satellite distance
            r2 = np.linalg.norm(np.array([satx, saty, satz])-np.array(diob_xyz))
            # if we have a previous measurement, within 10 sec ...
            if t1 is not None and (t2 - t1).total_seconds() <= 10.:
                # computed range-rate
                crr = (r2 - r1) / (float((t2-t1).total_nanoseconds()) * 1e-9)
                # observed range-rate
                orr = (((L3 - L1) / (float((t2-t1).total_nanoseconds()) * 1e-9)) + frT - frN) * (299792458.0 / feN_L3)
                # very loose outlier detection
                if abs(orr - crr) > 100.:
                    pass
                else:
                    t.append(at2pt(t2))
                    res2.append(orr - crr)
                    raw_obs.append({
                        'rsat1': np.array([satx_prev, saty_prev, satz_prev]),
                        'rsat2': rsat2,
                        'dt': (float((t2-t1).total_nanoseconds()) * 1e-9),
                        'v_obs': orr,
                        'dT': dT,
                    })
            # prepare for next measurement
            r1 = r2
            t1 = t2
            L1 = L3
            satx_prev, saty_prev, satz_prev = satx, saty, satz
# Out:
# feN2 (2 GHz channel) = 2036272526.264190674 Hz
# feN4 (400 MHz channel) = 401254438.877105713 Hz
# [DEBUG] Παρατήρηση: el = 0.008035 m
# [DEBUG] Παρατήρηση: el = 0.007919 m
# [DEBUG] Παρατήρηση: el = 0.007850 m
# [DEBUG] Παρατήρηση: el = 0.007642 m
# [DEBUG] Παρατήρηση: el = 0.007534 m
# [DEBUG] Παρατήρηση: el = 0.007237 m
# [DEBUG] Παρατήρηση: el = 0.007090 m
# [DEBUG] Παρατήρηση: el = 0.110679 m
# [DEBUG] Παρατήρηση: el = 0.117568 m
# [DEBUG] Παρατήρηση: el = 0.120539 m
# [DEBUG] Παρατήρηση: el = 0.127518 m
# [DEBUG] Παρατήρηση: el = 0.130529 m
# [DEBUG] Παρατήρηση: el = 0.137601 m
# [DEBUG] Παρατήρηση: el = 0.140652 m
# [DEBUG] Παρατήρηση: el = 0.147818 m
# [DEBUG] Παρατήρηση: el = 0.150910 m
# [DEBUG] Παρατήρηση: el = 0.158173 m
# [DEBUG] Παρατήρηση: el = 0.161307 m
# [DEBUG] Παρατήρηση: el = 0.168670 m
# [DEBUG] Παρατήρηση: el = 0.171847 m
# [DEBUG] Παρατήρηση: el = 0.179310 m
# [DEBUG] Παρατήρηση: el = 0.182531 m
# [DEBUG] Παρατήρηση: el = 0.190097 m
# [DEBUG] Παρατήρηση: el = 0.193362 m
# [DEBUG] Παρατήρηση: el = 0.201033 m
# [DEBUG] Παρατήρηση: el = 0.204343 m
# [DEBUG] Παρατήρηση: el = 0.212119 m
# [DEBUG] Παρατήρηση: el = 0.215475 m
# [DEBUG] Παρατήρηση: el = 0.223359 m
# [DEBUG] Παρατήρηση: el = 0.226761 m
# [DEBUG] Παρατήρηση: el = 0.234753 m
# [DEBUG] Παρατήρηση: el = 0.238201 m
# [DEBUG] Παρατήρηση: el = 0.246302 m
# [DEBUG] Παρατήρηση: el = 0.249797 m
# [DEBUG] Παρατήρηση: el = 0.258006 m
# [DEBUG] Παρατήρηση: el = 0.261548 m
# [DEBUG] Παρατήρηση: el = 0.269866 m
# [DEBUG] Παρατήρηση: el = 0.273454 m
# [DEBUG] Παρατήρηση: el = 0.281880 m
# [DEBUG] Παρατήρηση: el = 0.285514 m
# [DEBUG] Παρατήρηση: el = 0.294046 m
# [DEBUG] Παρατήρηση: el = 0.297726 m
# [DEBUG] Παρατήρηση: el = 0.306362 m
# [DEBUG] Παρατήρηση: el = 0.310085 m
# [DEBUG] Παρατήρηση: el = 0.318823 m
# [DEBUG] Παρατήρηση: el = 0.322589 m
# [DEBUG] Παρατήρηση: el = 0.331423 m
# [DEBUG] Παρατήρηση: el = 0.335230 m
# [DEBUG] Παρατήρηση: el = 0.344156 m
# [DEBUG] Παρατήρηση: el = 0.348001 m
# [DEBUG] Παρατήρηση: el = 0.357013 m
# [DEBUG] Παρατήρηση: el = 0.360892 m
# [DEBUG] Παρατήρηση: el = 0.369982 m
# [DEBUG] Παρατήρηση: el = 0.373893 m
# [DEBUG] Παρατήρηση: el = 0.383051 m
# [DEBUG] Παρατήρηση: el = 0.386989 m
# [DEBUG] Παρατήρηση: el = 0.396205 m
# [DEBUG] Παρατήρηση: el = 0.400165 m
# [DEBUG] Παρατήρηση: el = 0.409425 m
# [DEBUG] Παρατήρηση: el = 0.413401 m
# [DEBUG] Παρατήρηση: el = 0.422689 m
# [DEBUG] Παρατήρηση: el = 0.426674 m
# [DEBUG] Παρατήρηση: el = 0.435974 m
# [DEBUG] Παρατήρηση: el = 0.439959 m
# [DEBUG] Παρατήρηση: el = 0.449251 m
# [DEBUG] Παρατήρηση: el = 0.453228 m
# [DEBUG] Παρατήρηση: el = 0.462488 m
# [DEBUG] Παρατήρηση: el = 0.466446 m
# [DEBUG] Παρατήρηση: el = 0.475650 m
# [DEBUG] Παρατήρηση: el = 0.479577 m
# [DEBUG] Παρατήρηση: el = 0.488695 m
# [DEBUG] Παρατήρηση: el = 0.492579 m
# [DEBUG] Παρατήρηση: el = 0.501579 m
# [DEBUG] Παρατήρηση: el = 0.505406 m
# [DEBUG] Παρατήρηση: el = 0.514253 m
# [DEBUG] Παρατήρηση: el = 0.518007 m
# [DEBUG] Παρατήρηση: el = 0.526664 m
# [DEBUG] Παρατήρηση: el = 0.530327 m
# [DEBUG] Παρατήρηση: el = 0.538752 m
# [DEBUG] Παρατήρηση: el = 0.542306 m
# [DEBUG] Παρατήρηση: el = 0.550456 m
# [DEBUG] Παρατήρηση: el = 0.553882 m
# [DEBUG] Παρατήρηση: el = 0.561710 m
# [DEBUG] Παρατήρηση: el = 0.564988 m
# [DEBUG] Παρατήρηση: el = 0.572445 m
# [DEBUG] Παρατήρηση: el = 0.575553 m
# [DEBUG] Παρατήρηση: el = 0.582589 m
# [DEBUG] Παρατήρηση: el = 0.585506 m
# [DEBUG] Παρατήρηση: el = 0.592071 m
# [DEBUG] Παρατήρηση: el = 0.594775 m
# [DEBUG] Παρατήρηση: el = 0.600817 m
# [DEBUG] Παρατήρηση: el = 0.603287 m
# [DEBUG] Παρατήρηση: el = 0.608756 m
# [DEBUG] Παρατήρηση: el = 0.610971 m
# [DEBUG] Παρατήρηση: el = 0.615821 m
# [DEBUG] Παρατήρηση: el = 0.617759 m
# [DEBUG] Παρατήρηση: el = 0.621945 m
# [DEBUG] Παρατήρηση: el = 0.623591 m
# [DEBUG] Παρατήρηση: el = 0.608624 m
# [DEBUG] Παρατήρηση: el = 0.603154 m
# [DEBUG] Παρατήρηση: el = 0.600685 m
# [DEBUG] Παρατήρηση: el = 0.594647 m
# [DEBUG] Παρατήρηση: el = 0.591945 m
# [DEBUG] Παρατήρηση: el = 0.585389 m
# [DEBUG] Παρατήρηση: el = 0.582476 m
# [DEBUG] Παρατήρηση: el = 0.575452 m
# [DEBUG] Παρατήρηση: el = 0.572350 m
# [DEBUG] Παρατήρηση: el = 0.564909 m
# [DEBUG] Παρατήρηση: el = 0.561639 m
# [DEBUG] Παρατήρηση: el = 0.553832 m
# [DEBUG] Παρατήρηση: el = 0.550415 m
# [DEBUG] Παρατήρηση: el = 0.542289 m
# [DEBUG] Παρατήρηση: el = 0.538745 m
# [DEBUG] Παρατήρηση: el = 0.530347 m
# [DEBUG] Παρατήρηση: el = 0.526696 m
# [DEBUG] Παρατήρηση: el = 0.518069 m
# [DEBUG] Παρατήρηση: el = 0.514329 m
# [DEBUG] Παρατήρηση: el = 0.505513 m
# [DEBUG] Παρατήρηση: el = 0.501701 m
# [DEBUG] Παρατήρηση: el = 0.492735 m
# [DEBUG] Παρατήρηση: el = 0.488866 m
# [DEBUG] Παρατήρηση: el = 0.479785 m
# [DEBUG] Παρατήρηση: el = 0.475873 m
# [DEBUG] Παρατήρηση: el = 0.466707 m
# [DEBUG] Παρατήρηση: el = 0.462765 m
# [DEBUG] Παρατήρηση: el = 0.453543 m
# [DEBUG] Παρατήρηση: el = 0.449583 m
# [DEBUG] Παρατήρηση: el = 0.440330 m
# [DEBUG] Παρατήρηση: el = 0.436362 m
# [DEBUG] Παρατήρηση: el = 0.427101 m
# [DEBUG] Παρατήρηση: el = 0.423133 m
# [DEBUG] Παρατήρηση: el = 0.413884 m
# [DEBUG] Παρατήρηση: el = 0.409925 m
# [DEBUG] Παρατήρηση: el = 0.400705 m
# [DEBUG] Παρατήρηση: el = 0.396762 m
# [DEBUG] Παρατήρηση: el = 0.387585 m
# [DEBUG] Παρατήρηση: el = 0.383664 m
# [DEBUG] Παρατήρηση: el = 0.374544 m
# [DEBUG] Παρατήρηση: el = 0.370650 m
# [DEBUG] Παρατήρηση: el = 0.361598 m
# [DEBUG] Παρατήρηση: el = 0.357734 m
# [DEBUG] Παρατήρηση: el = 0.348759 m
# [DEBUG] Παρατήρηση: el = 0.344930 m
# [DEBUG] Παρατήρηση: el = 0.336039 m
# [DEBUG] Παρατήρηση: el = 0.332248 m
# [DEBUG] Παρατήρηση: el = 0.323449 m
# [DEBUG] Παρατήρηση: el = 0.319698 m
# [DEBUG] Παρατήρηση: el = 0.310994 m
# [DEBUG] Παρατήρηση: el = 0.307285 m
# [DEBUG] Παρατήρηση: el = 0.298681 m
# [DEBUG] Παρατήρηση: el = 0.295015 m
# [DEBUG] Παρατήρηση: el = 0.286514 m
# [DEBUG] Παρατήρηση: el = 0.282893 m
# [DEBUG] Παρατήρηση: el = 0.274497 m
# [DEBUG] Παρατήρηση: el = 0.270921 m
# [DEBUG] Παρατήρηση: el = 0.262631 m
# [DEBUG] Παρατήρηση: el = 0.259102 m
# [DEBUG] Παρατήρηση: el = 0.250919 m
# [DEBUG] Παρατήρηση: el = 0.247435 m
# [DEBUG] Παρατήρηση: el = 0.239361 m
# [DEBUG] Παρατήρηση: el = 0.235923 m
# [DEBUG] Παρατήρηση: el = 0.191392 m
# [DEBUG] Παρατήρηση: el = 0.183845 m
# [DEBUG] Παρατήρηση: el = 0.180632 m
# [DEBUG] Παρατήρηση: el = 0.139008 m
# [DEBUG] Παρατήρηση: el = 0.131949 m
# [DEBUG] Παρατήρηση: el = 0.128943 m
# [DEBUG] Παρατήρηση: el = 0.121974 m
# [DEBUG] Παρατήρηση: el = 0.119007 m
# [DEBUG] Παρατήρηση: el = 0.112128 m
# [DEBUG] Παρατήρηση: el = 0.109199 m
# [DEBUG] Παρατήρηση: el = 0.102407 m
# [DEBUG] Παρατήρηση: el = 0.099514 m
# [DEBUG] Παρατήρηση: el = 0.092807 m
# [DEBUG] Παρατήρηση: el = 0.089950 m
# [DEBUG] Παρατήρηση: el = 0.080504 m
# [DEBUG] Παρατήρηση: el = 0.073960 m
# [DEBUG] Παρατήρηση: el = 0.071172 m
# [DEBUG] Παρατήρηση: el = 0.064706 m
# [DEBUG] Παρατήρηση: el = 0.061951 m
# [DEBUG] Παρατήρηση: el = 0.055561 m
# [DEBUG] Παρατήρηση: el = 0.052839 m
# [DEBUG] Παρατήρηση: el = 0.046523 m
# [DEBUG] Παρατήρηση: el = 0.043831 m
# [DEBUG] Παρατήρηση: el = 0.037587 m
# [DEBUG] Παρατήρηση: el = 0.034926 m
# [DEBUG] Παρατήρηση: el = 0.028752 m
# [DEBUG] Παρατήρηση: el = 0.026121 m
# [DEBUG] Παρατήρηση: el = 0.020014 m
# [DEBUG] Παρατήρηση: el = 0.017411 m
# [DEBUG] Παρατήρηση: el = 0.011371 m
# [DEBUG] Παρατήρηση: el = 0.008796 m
# [DEBUG] Παρατήρηση: el = 0.002819 m
# [DEBUG] Παρατήρηση: el = 0.000272 m
# [DEBUG] Παρατήρηση: el = 0.148285 m
# [DEBUG] Παρατήρηση: el = 0.155948 m
# [DEBUG] Παρατήρηση: el = 0.159260 m
# [DEBUG] Παρατήρηση: el = 0.167055 m
# [DEBUG] Παρατήρηση: el = 0.170425 m
# [DEBUG] Παρατήρηση: el = 0.178357 m
# [DEBUG] Παρατήρηση: el = 0.181786 m
# [DEBUG] Παρατήρηση: el = 0.189860 m
# [DEBUG] Παρατήρηση: el = 0.193352 m
# [DEBUG] Παρατήρηση: el = 0.201574 m
# [DEBUG] Παρατήρηση: el = 0.205130 m
# [DEBUG] Παρατήρηση: el = 0.213504 m
# [DEBUG] Παρατήρηση: el = 0.217127 m
# [DEBUG] Παρατήρηση: el = 0.225660 m
# [DEBUG] Παρατήρηση: el = 0.229352 m
# [DEBUG] Παρατήρηση: el = 0.238049 m
# [DEBUG] Παρατήρηση: el = 0.241813 m
# [DEBUG] Παρατήρηση: el = 0.250681 m
# [DEBUG] Παρατήρηση: el = 0.254518 m
# [DEBUG] Παρατήρηση: el = 0.263562 m
# [DEBUG] Παρατήρηση: el = 0.267477 m
# [DEBUG] Παρατήρηση: el = 0.276703 m
# [DEBUG] Παρατήρηση: el = 0.280697 m
# [DEBUG] Παρατήρηση: el = 0.290111 m
# [DEBUG] Παρατήρηση: el = 0.294187 m
# [DEBUG] Παρατήρηση: el = 0.303795 m
# [DEBUG] Παρατήρηση: el = 0.307956 m
# [DEBUG] Παρατήρηση: el = 0.317765 m
# [DEBUG] Παρατήρηση: el = 0.322012 m
# [DEBUG] Παρατήρηση: el = 0.332027 m
# [DEBUG] Παρατήρηση: el = 0.336364 m
# [DEBUG] Παρατήρηση: el = 0.346591 m
# [DEBUG] Παρατήρηση: el = 0.351020 m
# [DEBUG] Παρατήρηση: el = 0.361463 m
# [DEBUG] Παρατήρηση: el = 0.365987 m
# [DEBUG] Παρατήρηση: el = 0.376652 m
# [DEBUG] Παρατήρηση: el = 0.381271 m
# [DEBUG] Παρατήρηση: el = 0.392162 m
# [DEBUG] Παρατήρηση: el = 0.396879 m
# [DEBUG] Παρατήρηση: el = 0.408000 m
# [DEBUG] Παρατήρηση: el = 0.412816 m
# [DEBUG] Παρατήρηση: el = 0.424169 m
# [DEBUG] Παρατήρηση: el = 0.429085 m
# [DEBUG] Παρατήρηση: el = 0.440671 m
# [DEBUG] Παρατήρηση: el = 0.445687 m
# [DEBUG] Παρατήρηση: el = 0.457507 m
# [DEBUG] Παρατήρηση: el = 0.462623 m
# [DEBUG] Παρατήρηση: el = 0.474675 m
# [DEBUG] Παρατήρηση: el = 0.479889 m
# [DEBUG] Παρατήρηση: el = 0.492169 m
# [DEBUG] Παρατήρηση: el = 0.497480 m
# [DEBUG] Παρατήρηση: el = 0.509982 m
# [DEBUG] Παρατήρηση: el = 0.515385 m
# [DEBUG] Παρατήρηση: el = 0.528099 m
# [DEBUG] Παρατήρηση: el = 0.533591 m
# [DEBUG] Παρατήρηση: el = 0.546503 m
# [DEBUG] Παρατήρηση: el = 0.552077 m
# [DEBUG] Παρατήρηση: el = 0.565172 m
# [DEBUG] Παρατήρηση: el = 0.570819 m
# [DEBUG] Παρατήρηση: el = 0.584074 m
# [DEBUG] Παρατήρηση: el = 0.589785 m
# [DEBUG] Παρατήρηση: el = 0.603171 m
# [DEBUG] Παρατήρηση: el = 0.608932 m
# [DEBUG] Παρατήρηση: el = 0.622418 m
# [DEBUG] Παρατήρηση: el = 0.628212 m
# [DEBUG] Παρατήρηση: el = 0.641756 m
# [DEBUG] Παρατήρηση: el = 0.647566 m
# [DEBUG] Παρατήρηση: el = 0.661118 m
# [DEBUG] Παρατήρηση: el = 0.666920 m
# [DEBUG] Παρατήρηση: el = 0.680424 m
# [DEBUG] Παρατήρηση: el = 0.686190 m
# [DEBUG] Παρατήρηση: el = 0.699578 m
# [DEBUG] Παρατήρηση: el = 0.705280 m
# [DEBUG] Παρατήρηση: el = 0.718474 m
# [DEBUG] Παρατήρηση: el = 0.724074 m
# [DEBUG] Παρατήρηση: el = 0.736988 m
# [DEBUG] Παρατήρηση: el = 0.742447 m
# [DEBUG] Παρατήρηση: el = 0.754981 m
# [DEBUG] Παρατήρηση: el = 0.760255 m
# [DEBUG] Παρατήρηση: el = 0.772300 m
# [DEBUG] Παρατήρηση: el = 0.777340 m
# [DEBUG] Παρατήρηση: el = 0.788778 m
# [DEBUG] Παρατήρηση: el = 0.793532 m
# [DEBUG] Παρατήρηση: el = 0.804238 m
# [DEBUG] Παρατήρηση: el = 0.808650 m
# [DEBUG] Παρατήρηση: el = 0.818493 m
# [DEBUG] Παρατήρηση: el = 0.822507 m
# [DEBUG] Παρατήρηση: el = 0.831355 m
# [DEBUG] Παρατήρηση: el = 0.834913 m
# [DEBUG] Παρατήρηση: el = 0.842635 m
# [DEBUG] Παρατήρηση: el = 0.845685 m
# [DEBUG] Παρατήρηση: el = 0.852159 m
# [DEBUG] Παρατήρηση: el = 0.854648 m
# [DEBUG] Παρατήρηση: el = 0.859765 m
# [DEBUG] Παρατήρηση: el = 0.861652 m
# [DEBUG] Παρατήρηση: el = 0.865319 m
# [DEBUG] Παρατήρηση: el = 0.866568 m
# [DEBUG] Παρατήρηση: el = 0.868718 m
# [DEBUG] Παρατήρηση: el = 0.869307 m
# [DEBUG] Παρατήρηση: el = 0.869900 m
# [DEBUG] Παρατήρηση: el = 0.869818 m
# [DEBUG] Παρατήρηση: el = 0.868842 m
# [DEBUG] Παρατήρηση: el = 0.868090 m
# [DEBUG] Παρατήρηση: el = 0.865567 m
# [DEBUG] Παρατήρηση: el = 0.864160 m
# [DEBUG] Παρατήρηση: el = 0.860139 m
# [DEBUG] Παρατήρηση: el = 0.858105 m
# [DEBUG] Παρατήρηση: el = 0.852660 m
# [DEBUG] Παρατήρηση: el = 0.850036 m
# [DEBUG] Παρατήρηση: el = 0.843267 m
# [DEBUG] Παρατήρηση: el = 0.840098 m
# [DEBUG] Παρατήρηση: el = 0.832118 m
# [DEBUG] Παρατήρηση: el = 0.828457 m
# [DEBUG] Παρατήρηση: el = 0.819391 m
# [DEBUG] Παρατήρηση: el = 0.815293 m
# [DEBUG] Παρατήρηση: el = 0.805273 m
# [DEBUG] Παρατήρηση: el = 0.800794 m
# [DEBUG] Παρατήρηση: el = 0.789952 m
# [DEBUG] Παρατήρηση: el = 0.785149 m
# [DEBUG] Παρατήρηση: el = 0.773614 m
# [DEBUG] Παρατήρηση: el = 0.768541 m
# [DEBUG] Παρατήρηση: el = 0.756437 m
# [DEBUG] Παρατήρηση: el = 0.751145 m
# [DEBUG] Παρατήρηση: el = 0.738586 m
# [DEBUG] Παρατήρηση: el = 0.733123 m
# [DEBUG] Παρατήρηση: el = 0.720216 m
# [DEBUG] Παρατήρηση: el = 0.714624 m
# [DEBUG] Παρατήρηση: el = 0.701463 m
# [DEBUG] Παρατήρηση: el = 0.695781 m
# [DEBUG] Παρατήρηση: el = 0.682450 m
# [DEBUG] Παρατήρηση: el = 0.676712 m
# [DEBUG] Παρατήρηση: el = 0.663286 m
# [DEBUG] Παρατήρηση: el = 0.657521 m
# [DEBUG] Παρατήρηση: el = 0.644064 m
# [DEBUG] Παρατήρηση: el = 0.638298 m
# [DEBUG] Παρατήρηση: el = 0.624863 m
# [DEBUG] Παρατήρηση: el = 0.619117 m
# [DEBUG] Παρατήρηση: el = 0.605752 m
# [DEBUG] Παρατήρηση: el = 0.600045 m
# [DEBUG] Παρατήρηση: el = 0.586787 m
# [DEBUG] Παρατήρηση: el = 0.581134 m
# [DEBUG] Παρατήρηση: el = 0.568016 m
# [DEBUG] Παρατήρηση: el = 0.562428 m
# [DEBUG] Παρατήρηση: el = 0.549475 m
# [DEBUG] Παρατήρηση: el = 0.543962 m
# [DEBUG] Παρατήρηση: el = 0.531195 m
# [DEBUG] Παρατήρηση: el = 0.525765 m
# [DEBUG] Παρατήρηση: el = 0.513199 m
# [DEBUG] Παρατήρηση: el = 0.507858 m
# [DEBUG] Παρατήρηση: el = 0.495505 m
# [DEBUG] Παρατήρηση: el = 0.490258 m
# [DEBUG] Παρατήρηση: el = 0.478126 m
# [DEBUG] Παρατήρηση: el = 0.472975 m
# [DEBUG] Παρατήρηση: el = 0.461071 m
# [DEBUG] Παρατήρηση: el = 0.456018 m
# [DEBUG] Παρατήρηση: el = 0.444344 m
# [DEBUG] Παρατήρηση: el = 0.439390 m
# [DEBUG] Παρατήρηση: el = 0.427948 m
# [DEBUG] Παρατήρηση: el = 0.423094 m
# [DEBUG] Παρατήρηση: el = 0.411883 m
# [DEBUG] Παρατήρηση: el = 0.407127 m
# [DEBUG] Παρατήρηση: el = 0.396146 m
# [DEBUG] Παρατήρηση: el = 0.391489 m
# [DEBUG] Παρατήρηση: el = 0.380734 m
# [DEBUG] Παρατήρηση: el = 0.376173 m
# [DEBUG] Παρατήρηση: el = 0.365641 m
# [DEBUG] Παρατήρηση: el = 0.361175 m
# [DEBUG] Παρατήρηση: el = 0.350862 m
# [DEBUG] Παρατήρηση: el = 0.346489 m
# [DEBUG] Παρατήρηση: el = 0.336390 m
# [DEBUG] Παρατήρηση: el = 0.332107 m
# [DEBUG] Παρατήρηση: el = 0.322216 m
# [DEBUG] Παρατήρηση: el = 0.318022 m
# [DEBUG] Παρατήρηση: el = 0.308334 m
# [DEBUG] Παρατήρηση: el = 0.304225 m
# [DEBUG] Παρατήρηση: el = 0.294735 m
# [DEBUG] Παρατήρηση: el = 0.290709 m
# [DEBUG] Παρατήρηση: el = 0.281410 m
# [DEBUG] Παρατήρηση: el = 0.277465 m
# [DEBUG] Παρατήρηση: el = 0.268351 m
# [DEBUG] Παρατήρηση: el = 0.264484 m
# [DEBUG] Παρατήρηση: el = 0.255550 m
# [DEBUG] Παρατήρηση: el = 0.251758 m
# [DEBUG] Παρατήρηση: el = 0.242997 m
# [DEBUG] Παρατήρηση: el = 0.239279 m
# [DEBUG] Παρατήρηση: el = 0.230685 m
# [DEBUG] Παρατήρηση: el = 0.227037 m
# [DEBUG] Παρατήρηση: el = 0.218605 m
# [DEBUG] Παρατήρηση: el = 0.215025 m
# [DEBUG] Παρατήρηση: el = 0.206750 m
# [DEBUG] Παρατήρηση: el = 0.203236 m
# [DEBUG] Παρατήρηση: el = 0.195110 m
# [DEBUG] Παρατήρηση: el = 0.191660 m
# [DEBUG] Παρατήρηση: el = 0.158140 m
# [DEBUG] Παρατήρηση: el = 0.150565 m
# [DEBUG] Παρατήρηση: el = 0.147346 m
# [DEBUG] Παρατήρηση: el = 0.139896 m
# [DEBUG] Παρατήρηση: el = 0.136730 m
# [DEBUG] Παρατήρηση: el = 0.129401 m
# [DEBUG] Παρατήρηση: el = 0.126285 m
# [DEBUG] Παρατήρηση: el = 0.119072 m
# [DEBUG] Παρατήρηση: el = 0.116005 m
# [DEBUG] Παρατήρηση: el = 0.108905 m
# [DEBUG] Παρατήρηση: el = 0.105885 m
# [DEBUG] Παρατήρηση: el = 0.098893 m
# [DEBUG] Παρατήρηση: el = 0.095919 m
# [DEBUG] Παρατήρηση: el = 0.089031 m
# [DEBUG] Παρατήρηση: el = 0.086100 m
# [DEBUG] Παρατήρηση: el = 0.066886 m
# [DEBUG] Παρατήρηση: el = 0.060288 m
# [DEBUG] Παρατήρηση: el = 0.057480 m
# [DEBUG] Παρατήρηση: el = 0.050973 m
# [DEBUG] Παρατήρηση: el = 0.048202 m
# [DEBUG] Παρατήρηση: el = 0.041782 m
# [DEBUG] Παρατήρηση: el = 0.039048 m
# [DEBUG] Παρατήρηση: el = 0.032711 m
# [DEBUG] Παρατήρηση: el = 0.030012 m
# [DEBUG] Παρατήρηση: el = 0.023756 m
# [DEBUG] Παρατήρηση: el = 0.021092 m
# [DEBUG] Παρατήρηση: el = 0.134679 m
# [DEBUG] Παρατήρηση: el = 0.138744 m
# [DEBUG] Παρατήρηση: el = 0.140475 m
# [DEBUG] Παρατήρηση: el = 0.144484 m
# [DEBUG] Παρατήρηση: el = 0.146190 m
# [DEBUG] Παρατήρηση: el = 0.150138 m
# [DEBUG] Παρατήρηση: el = 0.151816 m
# [DEBUG] Παρατήρηση: el = 0.155698 m
# [DEBUG] Παρατήρηση: el = 0.157347 m
# [DEBUG] Παρατήρηση: el = 0.161159 m
# [DEBUG] Παρατήρηση: el = 0.162776 m
# [DEBUG] Παρατήρηση: el = 0.166512 m
# [DEBUG] Παρατήρηση: el = 0.168095 m
# [DEBUG] Παρατήρηση: el = 0.171749 m
# [DEBUG] Παρατήρηση: el = 0.173297 m
# [DEBUG] Παρατήρηση: el = 0.176863 m
# [DEBUG] Παρατήρηση: el = 0.178372 m
# [DEBUG] Παρατήρηση: el = 0.181846 m
# [DEBUG] Παρατήρηση: el = 0.183314 m
# [DEBUG] Παρατήρηση: el = 0.186690 m
# [DEBUG] Παρατήρηση: el = 0.188114 m
# [DEBUG] Παρατήρηση: el = 0.191385 m
# [DEBUG] Παρατήρηση: el = 0.192764 m
# [DEBUG] Παρατήρηση: el = 0.195925 m
# [DEBUG] Παρατήρηση: el = 0.197255 m
# [DEBUG] Παρατήρηση: el = 0.200300 m
# [DEBUG] Παρατήρηση: el = 0.201579 m
# [DEBUG] Παρατήρηση: el = 0.204502 m
# [DEBUG] Παρατήρηση: el = 0.205727 m
# [DEBUG] Παρατήρηση: el = 0.208522 m
# [DEBUG] Παρατήρηση: el = 0.209692 m
# [DEBUG] Παρατήρηση: el = 0.212353 m
# [DEBUG] Παρατήρηση: el = 0.213464 m
# [DEBUG] Παρατήρηση: el = 0.215985 m
# [DEBUG] Παρατήρηση: el = 0.217035 m
# [DEBUG] Παρατήρηση: el = 0.219412 m
# [DEBUG] Παρατήρηση: el = 0.220398 m
# [DEBUG] Παρατήρηση: el = 0.222624 m
# [DEBUG] Παρατήρηση: el = 0.223545 m
# [DEBUG] Παρατήρηση: el = 0.225616 m
# [DEBUG] Παρατήρηση: el = 0.226469 m
# [DEBUG] Παρατήρηση: el = 0.228379 m
# [DEBUG] Παρατήρηση: el = 0.229162 m
# [DEBUG] Παρατήρηση: el = 0.230906 m
# [DEBUG] Παρατήρηση: el = 0.231618 m
# [DEBUG] Παρατήρηση: el = 0.233192 m
# [DEBUG] Παρατήρηση: el = 0.233830 m
# [DEBUG] Παρατήρηση: el = 0.235231 m
# [DEBUG] Παρατήρηση: el = 0.235794 m
# [DEBUG] Παρατήρηση: el = 0.237017 m
# [DEBUG] Παρατήρηση: el = 0.237503 m
# [DEBUG] Παρατήρηση: el = 0.238546 m
# [DEBUG] Παρατήρηση: el = 0.238954 m
# [DEBUG] Παρατήρηση: el = 0.239814 m
# [DEBUG] Παρατήρηση: el = 0.240143 m
# [DEBUG] Παρατήρηση: el = 0.240817 m
# [DEBUG] Παρατήρηση: el = 0.241066 m
# [DEBUG] Παρατήρηση: el = 0.241553 m
# [DEBUG] Παρατήρηση: el = 0.241721 m
# [DEBUG] Παρατήρηση: el = 0.242020 m
# [DEBUG] Παρατήρηση: el = 0.242107 m
# [DEBUG] Παρατήρηση: el = 0.242067 m
# [DEBUG] Παρατήρηση: el = 0.241797 m
# [DEBUG] Παρατήρηση: el = 0.241641 m
# [DEBUG] Παρατήρηση: el = 0.241183 m
# [DEBUG] Παρατήρηση: el = 0.240946 m
# [DEBUG] Παρατήρηση: el = 0.240301 m
# [DEBUG] Παρατήρηση: el = 0.239985 m
# [DEBUG] Παρατήρηση: el = 0.239154 m
# [DEBUG] Παρατήρηση: el = 0.238759 m
# [DEBUG] Παρατήρηση: el = 0.237746 m
# [DEBUG] Παρατήρηση: el = 0.237273 m
# [DEBUG] Παρατήρηση: el = 0.236080 m
# [DEBUG] Παρατήρηση: el = 0.235531 m
# [DEBUG] Παρατήρηση: el = 0.234162 m
# [DEBUG] Παρατήρηση: el = 0.233537 m
# [DEBUG] Παρατήρηση: el = 0.231995 m
# [DEBUG] Παρατήρηση: el = 0.231297 m
# [DEBUG] Παρατήρηση: el = 0.229586 m
# [DEBUG] Παρατήρηση: el = 0.228817 m
# [DEBUG] Παρατήρηση: el = 0.226941 m
# [DEBUG] Παρατήρηση: el = 0.226102 m
# [DEBUG] Παρατήρηση: el = 0.224066 m
# [DEBUG] Παρατήρηση: el = 0.223161 m
# [DEBUG] Παρατήρηση: el = 0.220970 m
# [DEBUG] Παρατήρηση: el = 0.219999 m
# [DEBUG] Παρατήρηση: el = 0.217659 m
# [DEBUG] Παρατήρηση: el = 0.216625 m
# [DEBUG] Παρατήρηση: el = 0.214141 m
# [DEBUG] Παρατήρηση: el = 0.213047 m
# [DEBUG] Παρατήρηση: el = 0.210425 m
# [DEBUG] Παρατήρηση: el = 0.209272 m
# [DEBUG] Παρατήρηση: el = 0.206517 m
# [DEBUG] Παρατήρηση: el = 0.205309 m
# [DEBUG] Παρατήρηση: el = 0.202427 m
# [DEBUG] Παρατήρηση: el = 0.201166 m
# [DEBUG] Παρατήρηση: el = 0.198163 m
# [DEBUG] Παρατήρηση: el = 0.196851 m
# [DEBUG] Παρατήρηση: el = 0.193734 m
# [DEBUG] Παρατήρηση: el = 0.192374 m
# [DEBUG] Παρατήρηση: el = 0.189147 m
# [DEBUG] Παρατήρηση: el = 0.187741 m
# [DEBUG] Παρατήρηση: el = 0.184411 m
# [DEBUG] Παρατήρηση: el = 0.182963 m
# [DEBUG] Παρατήρηση: el = 0.179535 m
# [DEBUG] Παρατήρηση: el = 0.178046 m
# [DEBUG] Παρατήρηση: el = 0.174527 m
# [DEBUG] Παρατήρηση: el = 0.173000 m
# [DEBUG] Παρατήρηση: el = 0.169395 m
# [DEBUG] Παρατήρηση: el = 0.167832 m
# [DEBUG] Παρατήρηση: el = 0.164146 m
# [DEBUG] Παρατήρηση: el = 0.162550 m
# [DEBUG] Παρατήρηση: el = 0.158789 m
# [DEBUG] Παρατήρηση: el = 0.157162 m
# [DEBUG] Παρατήρηση: el = 0.153330 m
# [DEBUG] Παρατήρηση: el = 0.151674 m
# [DEBUG] Παρατήρηση: el = 0.147778 m
# [DEBUG] Παρατήρηση: el = 0.146095 m
# [DEBUG] Παρατήρηση: el = 0.142139 m
# [DEBUG] Παρατήρηση: el = 0.140431 m
# [DEBUG] Παρατήρηση: el = 0.055454 m
# [DEBUG] Παρατήρηση: el = 0.051053 m
# [DEBUG] Παρατήρηση: el = 0.049165 m
# [DEBUG] Παρατήρηση: el = 0.044756 m
# [DEBUG] Παρατήρηση: el = 0.042865 m
# [DEBUG] Παρατήρηση: el = 0.038451 m
# [DEBUG] Παρατήρηση: el = 0.036559 m
# [DEBUG] Παρατήρηση: el = 0.032141 m
# [DEBUG] Παρατήρηση: el = 0.030247 m
# [DEBUG] Παρατήρηση: el = 0.025827 m
# [DEBUG] Παρατήρηση: el = 0.023933 m
# [DEBUG] Παρατήρηση: el = 0.019512 m
# [DEBUG] Παρατήρηση: el = 0.017618 m
# [DEBUG] Παρατήρηση: el = 0.111638 m
# [DEBUG] Παρατήρηση: el = 0.112928 m
# [DEBUG] Παρατήρηση: el = 0.113458 m
# [DEBUG] Παρατήρηση: el = 0.114640 m
# [DEBUG] Παρατήρηση: el = 0.115123 m
# [DEBUG] Παρατήρηση: el = 0.116194 m
# [DEBUG] Παρατήρηση: el = 0.116630 m
# [DEBUG] Παρατήρηση: el = 0.117590 m
# [DEBUG] Παρατήρηση: el = 0.117977 m
# [DEBUG] Παρατήρηση: el = 0.118824 m
# [DEBUG] Παρατήρηση: el = 0.119162 m
# [DEBUG] Παρατήρηση: el = 0.122787 m
# [DEBUG] Παρατήρηση: el = 0.122692 m
# [DEBUG] Παρατήρηση: el = 0.122626 m
# [DEBUG] Παρατήρηση: el = 0.122413 m
# [DEBUG] Παρατήρηση: el = 0.122296 m
# [DEBUG] Παρατήρηση: el = 0.121964 m
# [DEBUG] Παρατήρηση: el = 0.121796 m
# [DEBUG] Παρατήρηση: el = 0.121345 m
# [DEBUG] Παρατήρηση: el = 0.121127 m
# [DEBUG] Παρατήρηση: el = 0.120559 m
# [DEBUG] Παρατήρηση: el = 0.120291 m
# [DEBUG] Παρατήρηση: el = 0.119607 m
# [DEBUG] Παρατήρηση: el = 0.119289 m
# [DEBUG] Παρατήρηση: el = 0.118489 m
# [DEBUG] Παρατήρηση: el = 0.118122 m
# [DEBUG] Παρατήρηση: el = 0.117209 m
# [DEBUG] Παρατήρηση: el = 0.116793 m
# [DEBUG] Παρατήρηση: el = 0.115767 m
# [DEBUG] Παρατήρηση: el = 0.115303 m
# [DEBUG] Παρατήρηση: el = 0.114167 m
# [DEBUG] Παρατήρηση: el = 0.113656 m
# [DEBUG] Παρατήρηση: el = 0.112410 m
# [DEBUG] Παρατήρηση: el = 0.111853 m
# [DEBUG] Παρατήρηση: el = 0.110500 m
# [DEBUG] Παρατήρηση: el = 0.109898 m
# [DEBUG] Παρατήρηση: el = 0.108440 m
# [DEBUG] Παρατήρηση: el = 0.107793 m
# [DEBUG] Παρατήρηση: el = 0.106232 m
# [DEBUG] Παρατήρηση: el = 0.105542 m
# [DEBUG] Παρατήρηση: el = 0.103881 m
# [DEBUG] Παρατήρηση: el = 0.103148 m
# [DEBUG] Παρατήρηση: el = 0.101389 m
# [DEBUG] Παρατήρηση: el = 0.100615 m
# [DEBUG] Παρατήρηση: el = 0.098760 m
# [DEBUG] Παρατήρηση: el = 0.097946 m
# [DEBUG] Παρατήρηση: el = 0.095998 m
# [DEBUG] Παρατήρηση: el = 0.095144 m
# [DEBUG] Παρατήρηση: el = 0.093107 m
# [DEBUG] Παρατήρηση: el = 0.092215 m
# [DEBUG] Παρατήρηση: el = 0.090091 m
# [DEBUG] Παρατήρηση: el = 0.089162 m
# [DEBUG] Παρατήρηση: el = 0.056750 m
# [DEBUG] Παρατήρηση: el = 0.053906 m
# [DEBUG] Παρατήρηση: el = 0.052675 m
# [DEBUG] Παρατήρηση: el = 0.049775 m
# [DEBUG] Παρατήρηση: el = 0.048520 m
# [DEBUG] Παρατήρηση: el = 0.041282 m
# [DEBUG] Παρατήρηση: el = 0.039983 m
# [DEBUG] Παρατήρηση: el = 0.036928 m
# [DEBUG] Παρατήρηση: el = 0.035609 m
# [DEBUG] Παρατήρηση: el = 0.032507 m
# [DEBUG] Παρατήρηση: el = 0.031169 m
# [DEBUG] Παρατήρηση: el = 0.028023 m
# [DEBUG] Παρατήρηση: el = 0.026666 m
# [DEBUG] Παρατήρηση: el = 0.159931 m
# [DEBUG] Παρατήρηση: el = 0.164697 m
# [DEBUG] Παρατήρηση: el = 0.166732 m
# [DEBUG] Παρατήρηση: el = 0.171461 m
# [DEBUG] Παρατήρηση: el = 0.173480 m
# [DEBUG] Παρατήρηση: el = 0.178167 m
# [DEBUG] Παρατήρηση: el = 0.180167 m
# [DEBUG] Παρατήρηση: el = 0.184808 m
# [DEBUG] Παρατήρηση: el = 0.186786 m
# [DEBUG] Παρατήρηση: el = 0.191375 m
# [DEBUG] Παρατήρηση: el = 0.193329 m
# [DEBUG] Παρατήρηση: el = 0.197859 m
# [DEBUG] Παρατήρηση: el = 0.199787 m
# [DEBUG] Παρατήρηση: el = 0.204252 m
# [DEBUG] Παρατήρηση: el = 0.206151 m
# [DEBUG] Παρατήρηση: el = 0.210545 m
# [DEBUG] Παρατήρηση: el = 0.212412 m
# [DEBUG] Παρατήρηση: el = 0.216727 m
# [DEBUG] Παρατήρηση: el = 0.218559 m
# [DEBUG] Παρατήρηση: el = 0.222789 m
# [DEBUG] Παρατήρηση: el = 0.224582 m
# [DEBUG] Παρατήρηση: el = 0.228719 m
# [DEBUG] Παρατήρηση: el = 0.230471 m
# [DEBUG] Παρατήρηση: el = 0.234508 m
# [DEBUG] Παρατήρηση: el = 0.236215 m
# [DEBUG] Παρατήρηση: el = 0.240143 m
# [DEBUG] Παρατήρηση: el = 0.241802 m
# [DEBUG] Παρατήρηση: el = 0.245613 m
# [DEBUG] Παρατήρηση: el = 0.247221 m
# [DEBUG] Παρατήρηση: el = 0.250907 m
# [DEBUG] Παρατήρηση: el = 0.252459 m
# [DEBUG] Παρατήρηση: el = 0.256013 m
# [DEBUG] Παρατήρηση: el = 0.257506 m
# [DEBUG] Παρατήρηση: el = 0.260918 m
# [DEBUG] Παρατήρηση: el = 0.262348 m
# [DEBUG] Παρατήρηση: el = 0.265610 m
# [DEBUG] Παρατήρηση: el = 0.266975 m
# [DEBUG] Παρατήρηση: el = 0.270078 m
# [DEBUG] Παρατήρηση: el = 0.271373 m
# [DEBUG] Παρατήρηση: el = 0.274310 m
# [DEBUG] Παρατήρηση: el = 0.275532 m
# [DEBUG] Παρατήρηση: el = 0.278294 m
# [DEBUG] Παρατήρηση: el = 0.279439 m
# [DEBUG] Παρατήρηση: el = 0.282018 m
# [DEBUG] Παρατήρηση: el = 0.283083 m
# [DEBUG] Παρατήρηση: el = 0.285472 m
# [DEBUG] Παρατήρηση: el = 0.286454 m
# [DEBUG] Παρατήρηση: el = 0.288644 m
# [DEBUG] Παρατήρηση: el = 0.289540 m
# [DEBUG] Παρατήρηση: el = 0.291526 m
# [DEBUG] Παρατήρηση: el = 0.292333 m
# [DEBUG] Παρατήρηση: el = 0.294108 m
# [DEBUG] Παρατήρηση: el = 0.294822 m
# [DEBUG] Παρατήρηση: el = 0.296381 m
# [DEBUG] Παρατήρηση: el = 0.297001 m
# [DEBUG] Παρατήρηση: el = 0.298337 m
# [DEBUG] Παρατήρηση: el = 0.298861 m
# [DEBUG] Παρατήρηση: el = 0.299970 m
# [DEBUG] Παρατήρηση: el = 0.300396 m
# [DEBUG] Παρατήρηση: el = 0.301274 m
# [DEBUG] Παρατήρηση: el = 0.301601 m
# [DEBUG] Παρατήρηση: el = 0.302245 m
# [DEBUG] Παρατήρηση: el = 0.302470 m
# [DEBUG] Παρατήρηση: el = 0.302878 m
# [DEBUG] Παρατήρηση: el = 0.303002 m
# [DEBUG] Παρατήρηση: el = 0.303172 m
# [DEBUG] Παρατήρηση: el = 0.303194 m
# [DEBUG] Παρατήρηση: el = 0.303125 m
# [DEBUG] Παρατήρηση: el = 0.303045 m
# [DEBUG] Παρατήρηση: el = 0.302737 m
# [DEBUG] Παρατήρηση: el = 0.302555 m
# [DEBUG] Παρατήρηση: el = 0.302010 m
# [DEBUG] Παρατήρηση: el = 0.301726 m
# [DEBUG] Παρατήρηση: el = 0.300945 m
# [DEBUG] Παρατήρηση: el = 0.300560 m
# [DEBUG] Παρατήρηση: el = 0.299546 m
# [DEBUG] Παρατήρηση: el = 0.299062 m
# [DEBUG] Παρατήρηση: el = 0.297819 m
# [DEBUG] Παρατήρηση: el = 0.297237 m
# [DEBUG] Παρατήρηση: el = 0.295768 m
# [DEBUG] Παρατήρηση: el = 0.295090 m
# [DEBUG] Παρατήρηση: el = 0.293400 m
# [DEBUG] Παρατήρηση: el = 0.292629 m
# [DEBUG] Παρατήρηση: el = 0.290723 m
# [DEBUG] Παρατήρηση: el = 0.289861 m
# [DEBUG] Παρατήρηση: el = 0.287746 m
# [DEBUG] Παρατήρηση: el = 0.286795 m
# [DEBUG] Παρατήρηση: el = 0.284477 m
# [DEBUG] Παρατήρηση: el = 0.283441 m
# [DEBUG] Παρατήρηση: el = 0.280928 m
# [DEBUG] Παρατήρηση: el = 0.279809 m
# [DEBUG] Παρατήρηση: el = 0.277107 m
# [DEBUG] Παρατήρηση: el = 0.275910 m
# [DEBUG] Παρατήρηση: el = 0.273027 m
# [DEBUG] Παρατήρηση: el = 0.271754 m
# [DEBUG] Παρατήρηση: el = 0.268698 m
# [DEBUG] Παρατήρηση: el = 0.267353 m
# [DEBUG] Παρατήρηση: el = 0.264133 m
# [DEBUG] Παρατήρηση: el = 0.262719 m
# [DEBUG] Παρατήρηση: el = 0.259343 m
# [DEBUG] Παρατήρηση: el = 0.257864 m
# [DEBUG] Παρατήρηση: el = 0.254340 m
# [DEBUG] Παρατήρηση: el = 0.252800 m
# [DEBUG] Παρατήρηση: el = 0.249137 m
# [DEBUG] Παρατήρηση: el = 0.247539 m
# [DEBUG] Παρατήρηση: el = 0.243745 m
# [DEBUG] Παρατήρηση: el = 0.242093 m
# [DEBUG] Παρατήρηση: el = 0.238177 m
# [DEBUG] Παρατήρηση: el = 0.236474 m
# [DEBUG] Παρατήρηση: el = 0.232443 m
# [DEBUG] Παρατήρηση: el = 0.230693 m
# [DEBUG] Παρατήρηση: el = 0.226557 m
# [DEBUG] Παρατήρηση: el = 0.224762 m
# [DEBUG] Παρατήρηση: el = 0.220528 m
# [DEBUG] Παρατήρηση: el = 0.218693 m
# [DEBUG] Παρατήρηση: el = 0.214368 m
# [DEBUG] Παρατήρηση: el = 0.212496 m
# [DEBUG] Παρατήρηση: el = 0.208087 m
# [DEBUG] Παρατήρηση: el = 0.206181 m
# [DEBUG] Παρατήρηση: el = 0.201696 m
# [DEBUG] Παρατήρηση: el = 0.199759 m
# [DEBUG] Παρατήρηση: el = 0.195204 m
# [DEBUG] Παρατήρηση: el = 0.193239 m
# [DEBUG] Παρατήρηση: el = 0.188622 m
# [DEBUG] Παρατήρηση: el = 0.186630 m
# [DEBUG] Παρατήρηση: el = 0.181957 m
# [DEBUG] Παρατήρηση: el = 0.179942 m
# [DEBUG] Παρατήρηση: el = 0.175218 m
# [DEBUG] Παρατήρηση: el = 0.173183 m
# [DEBUG] Παρατήρηση: el = 0.168414 m
# [DEBUG] Παρατήρηση: el = 0.166361 m
# [DEBUG] Παρατήρηση: el = 0.161551 m
# [DEBUG] Παρατήρηση: el = 0.159482 m
# [DEBUG] Παρατήρηση: el = 0.154638 m
# [DEBUG] Παρατήρηση: el = 0.152556 m
# [DEBUG] Παρατήρηση: el = 0.147681 m
# [DEBUG] Παρατήρηση: el = 0.145587 m
# [DEBUG] Παρατήρηση: el = 0.140687 m
# [DEBUG] Παρατήρηση: el = 0.138582 m
# [DEBUG] Παρατήρηση: el = 0.133660 m
# [DEBUG] Παρατήρηση: el = 0.131547 m
# [DEBUG] Παρατήρηση: el = 0.126608 m
# [DEBUG] Παρατήρηση: el = 0.124488 m
# [DEBUG] Παρατήρηση: el = 0.119535 m
# [DEBUG] Παρατήρηση: el = 0.117409 m
# [DEBUG] Παρατήρηση: el = 0.112445 m
# [DEBUG] Παρατήρηση: el = 0.110316 m
# [DEBUG] Παρατήρηση: el = 0.105344 m
# [DEBUG] Παρατήρηση: el = 0.103212 m
# [DEBUG] Παρατήρηση: el = 0.098235 m
# [DEBUG] Παρατήρηση: el = 0.096101 m
# [DEBUG] Παρατήρηση: el = 0.091122 m
# [DEBUG] Παρατήρηση: el = 0.088988 m
# [DEBUG] Παρατήρηση: el = 0.053490 m
# [DEBUG] Παρατήρηση: el = 0.048541 m
# [DEBUG] Παρατήρηση: el = 0.046422 m
# [DEBUG] Παρατήρηση: el = 0.041484 m
# [DEBUG] Παρατήρηση: el = 0.039370 m
# [DEBUG] Παρατήρηση: el = 0.034444 m
# [DEBUG] Παρατήρηση: el = 0.032336 m
# [DEBUG] Παρατήρηση: el = 0.212116 m
# [DEBUG] Παρατήρηση: el = 0.220874 m
# [DEBUG] Παρατήρηση: el = 0.224669 m
# [DEBUG] Παρατήρηση: el = 0.233619 m
# [DEBUG] Παρατήρηση: el = 0.237497 m
# [DEBUG] Παρατήρηση: el = 0.246649 m
# [DEBUG] Παρατήρηση: el = 0.250615 m
# [DEBUG] Παρατήρηση: el = 0.259978 m
# [DEBUG] Παρατήρηση: el = 0.264037 m
# [DEBUG] Παρατήρηση: el = 0.273620 m
# [DEBUG] Παρατήρηση: el = 0.277775 m
# [DEBUG] Παρατήρηση: el = 0.287589 m
# [DEBUG] Παρατήρηση: el = 0.291847 m
# [DEBUG] Παρατήρηση: el = 0.301903 m
# [DEBUG] Παρατήρηση: el = 0.306266 m
# [DEBUG] Παρατήρηση: el = 0.316576 m
# [DEBUG] Παρατήρηση: el = 0.321051 m
# [DEBUG] Παρατήρηση: el = 0.331627 m
# [DEBUG] Παρατήρηση: el = 0.336218 m
# [DEBUG] Παρατήρηση: el = 0.347072 m
# [DEBUG] Παρατήρηση: el = 0.351786 m
# [DEBUG] Παρατήρηση: el = 0.362931 m
# [DEBUG] Παρατήρηση: el = 0.367773 m
# [DEBUG] Παρατήρηση: el = 0.379224 m
# [DEBUG] Παρατήρηση: el = 0.384199 m
# [DEBUG] Παρατήρηση: el = 0.395969 m
# [DEBUG] Παρατήρηση: el = 0.401085 m
# [DEBUG] Παρατήρηση: el = 0.413189 m
# [DEBUG] Παρατήρηση: el = 0.418451 m
# [DEBUG] Παρατήρηση: el = 0.430905 m
# [DEBUG] Παρατήρηση: el = 0.436320 m
# [DEBUG] Παρατήρηση: el = 0.449138 m
# [DEBUG] Παρατήρηση: el = 0.454713 m
# [DEBUG] Παρατήρηση: el = 0.467912 m
# [DEBUG] Παρατήρηση: el = 0.473652 m
# [DEBUG] Παρατήρηση: el = 0.487247 m
# [DEBUG] Παρατήρηση: el = 0.493161 m
# [DEBUG] Παρατήρηση: el = 0.507168 m
# [DEBUG] Παρατήρηση: el = 0.513261 m
# [DEBUG] Παρατήρηση: el = 0.527695 m
# [DEBUG] Παρατήρηση: el = 0.533974 m
# [DEBUG] Παρατήρηση: el = 0.548850 m
# [DEBUG] Παρατήρηση: el = 0.555322 m
# [DEBUG] Παρατήρηση: el = 0.570652 m
# [DEBUG] Παρατήρηση: el = 0.577322 m
# [DEBUG] Παρατήρηση: el = 0.593120 m
# [DEBUG] Παρατήρηση: el = 0.599992 m
# [DEBUG] Παρατήρηση: el = 0.616267 m
# [DEBUG] Παρατήρηση: el = 0.623346 m
# [DEBUG] Παρατήρηση: el = 0.640106 m
# [DEBUG] Παρατήρηση: el = 0.647393 m
# [DEBUG] Παρατήρηση: el = 0.664642 m
# [DEBUG] Παρατήρηση: el = 0.672138 m
# [DEBUG] Παρατήρηση: el = 0.689874 m
# [DEBUG] Παρατήρηση: el = 0.697578 m
# [DEBUG] Παρατήρηση: el = 0.715793 m
# [DEBUG] Παρατήρηση: el = 0.723700 m
# [DEBUG] Παρατήρηση: el = 0.742379 m
# [DEBUG] Παρατήρηση: el = 0.750481 m
# [DEBUG] Παρατήρηση: el = 0.769599 m
# [DEBUG] Παρατήρηση: el = 0.777882 m
# [DEBUG] Παρατήρηση: el = 0.797404 m
# [DEBUG] Παρατήρηση: el = 0.805849 m
# [DEBUG] Παρατήρηση: el = 0.825721 m
# [DEBUG] Παρατήρηση: el = 0.834303 m
# [DEBUG] Παρατήρηση: el = 0.854456 m
# [DEBUG] Παρατήρηση: el = 0.863140 m
# [DEBUG] Παρατήρηση: el = 0.883481 m
# [DEBUG] Παρατήρηση: el = 0.892222 m
# [DEBUG] Παρατήρηση: el = 0.912633 m
# [DEBUG] Παρατήρηση: el = 0.921374 m
# [DEBUG] Παρατήρηση: el = 0.941704 m
# [DEBUG] Παρατήρηση: el = 0.950372 m
# [DEBUG] Παρατήρηση: el = 0.970433 m
# [DEBUG] Παρατήρηση: el = 0.978939 m
# [DEBUG] Παρατήρηση: el = 0.998501 m
# [DEBUG] Παρατήρηση: el = 1.006736 m
# [DEBUG] Παρατήρηση: el = 1.025519 m
# [DEBUG] Παρατήρηση: el = 1.033353 m
# [DEBUG] Παρατήρηση: el = 1.051027 m
# [DEBUG] Παρατήρηση: el = 1.058308 m
# [DEBUG] Παρατήρηση: el = 1.074495 m
# [DEBUG] Παρατήρηση: el = 1.081050 m
# [DEBUG] Παρατήρηση: el = 1.095329 m
# [DEBUG] Παρατήρηση: el = 1.100972 m
# [DEBUG] Παρατήρηση: el = 1.112900 m
# [DEBUG] Παρατήρηση: el = 1.117441 m
# [DEBUG] Παρατήρηση: el = 1.126585 m
# [DEBUG] Παρατήρηση: el = 1.129847 m
# [DEBUG] Παρατήρηση: el = 1.135830 m
# [DEBUG] Παρατήρηση: el = 1.137670 m
# [DEBUG] Παρατήρηση: el = 1.140219 m
# [DEBUG] Παρατήρηση: el = 1.140551 m
# [DEBUG] Παρατήρηση: el = 1.139542 m
# [DEBUG] Παρατήρηση: el = 1.138349 m
# [DEBUG] Παρατήρηση: el = 1.133828 m
# [DEBUG] Παρατήρηση: el = 1.131165 m
# [DEBUG] Παρατήρηση: el = 1.123341 m
# [DEBUG] Παρατήρηση: el = 1.119328 m
# [DEBUG] Παρατήρηση: el = 1.108534 m
# [DEBUG] Παρατήρηση: el = 1.103335 m
# [DEBUG] Παρατήρηση: el = 1.089986 m
# [DEBUG] Παρατήρηση: el = 1.083786 m
# [DEBUG] Παρατήρηση: el = 1.068325 m
# [DEBUG] Παρατήρηση: el = 1.061313 m
# [DEBUG] Παρατήρηση: el = 1.044173 m
# [DEBUG] Παρατήρηση: el = 1.036531 m
# [DEBUG] Παρατήρηση: el = 1.018112 m
# [DEBUG] Παρατήρηση: el = 1.010000 m
# [DEBUG] Παρατήρηση: el = 0.990656 m
# [DEBUG] Παρατήρηση: el = 0.982216 m
# [DEBUG] Παρατήρηση: el = 0.962248 m
# [DEBUG] Παρατήρηση: el = 0.953597 m
# [DEBUG] Παρατήρηση: el = 0.933260 m
# [DEBUG] Παρατήρηση: el = 0.924497 m
# [DEBUG] Παρατήρηση: el = 0.903997 m
# [DEBUG] Παρατήρηση: el = 0.895203 m
# [DEBUG] Παρατήρηση: el = 0.874707 m
# [DEBUG] Παρατήρηση: el = 0.865946 m
# [DEBUG] Παρατήρηση: el = 0.845588 m
# [DEBUG] Παρατήρηση: el = 0.836910 m
# [DEBUG] Παρατήρηση: el = 0.816795 m
# [DEBUG] Παρατήρηση: el = 0.808240 m
# [DEBUG] Παρατήρηση: el = 0.788447 m
# [DEBUG] Παρατήρηση: el = 0.780044 m
# [DEBUG] Παρατήρηση: el = 0.760634 m
# [DEBUG] Παρατήρηση: el = 0.752405 m
# [DEBUG] Παρατήρηση: el = 0.733422 m
# [DEBUG] Παρατήρηση: el = 0.725383 m
# [DEBUG] Παρατήρηση: el = 0.706857 m
# [DEBUG] Παρατήρηση: el = 0.699019 m
# [DEBUG] Παρατήρηση: el = 0.680969 m
# [DEBUG] Παρατήρηση: el = 0.673338 m
# [DEBUG] Παρατήρηση: el = 0.655775 m
# [DEBUG] Παρατήρηση: el = 0.648354 m
# [DEBUG] Παρατήρηση: el = 0.631283 m
# [DEBUG] Παρατήρηση: el = 0.624072 m
# [DEBUG] Παρατήρηση: el = 0.607490 m
# [DEBUG] Παρατήρηση: el = 0.600488 m
# [DEBUG] Παρατήρηση: el = 0.584391 m
# [DEBUG] Παρατήρηση: el = 0.577595 m
# [DEBUG] Παρατήρηση: el = 0.561972 m
# [DEBUG] Παρατήρηση: el = 0.555377 m
# [DEBUG] Παρατήρηση: el = 0.540219 m
# [DEBUG] Παρατήρηση: el = 0.533820 m
# [DEBUG] Παρατήρηση: el = 0.519113 m
# [DEBUG] Παρατήρηση: el = 0.512904 m
# [DEBUG] Παρατήρηση: el = 0.498633 m
# [DEBUG] Παρατήρηση: el = 0.492608 m
# [DEBUG] Παρατήρηση: el = 0.478758 m
# [DEBUG] Παρατήρηση: el = 0.472910 m
# [DEBUG] Παρατήρηση: el = 0.459466 m
# [DEBUG] Παρατήρηση: el = 0.453788 m
# [DEBUG] Παρατήρηση: el = 0.440734 m
# [DEBUG] Παρατήρηση: el = 0.435220 m
# [DEBUG] Παρατήρηση: el = 0.422540 m
# [DEBUG] Παρατήρηση: el = 0.417183 m
# [DEBUG] Παρατήρηση: el = 0.404861 m
# [DEBUG] Παρατήρηση: el = 0.399654 m
# [DEBUG] Παρατήρηση: el = 0.387675 m
# [DEBUG] Παρατήρηση: el = 0.382612 m
# [DEBUG] Παρατήρηση: el = 0.370961 m
# [DEBUG] Παρατήρηση: el = 0.366036 m
# [DEBUG] Παρατήρηση: el = 0.354698 m
# [DEBUG] Παρατήρηση: el = 0.349904 m
# [DEBUG] Παρατήρηση: el = 0.338866 m
# [DEBUG] Παρατήρηση: el = 0.334197 m
# [DEBUG] Παρατήρηση: el = 0.323445 m
# [DEBUG] Παρατήρηση: el = 0.318896 m
# [DEBUG] Παρατήρηση: el = 0.308417 m
# [DEBUG] Παρατήρηση: el = 0.303982 m
# [DEBUG] Παρατήρηση: el = 0.293763 m
# [DEBUG] Παρατήρηση: el = 0.289437 m
# [DEBUG] Παρατήρηση: el = 0.279467 m
# [DEBUG] Παρατήρηση: el = 0.275245 m
# [DEBUG] Παρατήρηση: el = 0.265512 m
# [DEBUG] Παρατήρηση: el = 0.261390 m
# [DEBUG] Παρατήρηση: el = 0.251883 m
# [DEBUG] Παρατήρηση: el = 0.247856 m
# [DEBUG] Παρατήρηση: el = 0.238565 m
# [DEBUG] Παρατήρηση: el = 0.234628 m
# [DEBUG] Παρατήρηση: el = 0.225544 m
# [DEBUG] Παρατήρηση: el = 0.221694 m
# [DEBUG] Παρατήρηση: el = 0.212806 m
# [DEBUG] Παρατήρηση: el = 0.209038 m
# [DEBUG] Παρατήρηση: el = 0.200340 m
# [DEBUG] Παρατήρηση: el = 0.196650 m
# [DEBUG] Παρατήρηση: el = 0.188131 m
# [DEBUG] Παρατήρηση: el = 0.184517 m
# [DEBUG] Παρατήρηση: el = 0.176170 m
# [DEBUG] Παρατήρηση: el = 0.172628 m
# [DEBUG] Παρατήρηση: el = 0.164445 m
# [DEBUG] Παρατήρηση: el = 0.160973 m
# [DEBUG] Παρατήρηση: el = 0.152947 m
# [DEBUG] Παρατήρηση: el = 0.149540 m
# [DEBUG] Παρατήρηση: el = 0.141664 m
# [DEBUG] Παρατήρηση: el = 0.138320 m
# [DEBUG] Παρατήρηση: el = 0.130588 m
# [DEBUG] Παρατήρηση: el = 0.127304 m
# [DEBUG] Παρατήρηση: el = 0.119710 m
# [DEBUG] Παρατήρηση: el = 0.116484 m
# [DEBUG] Παρατήρηση: el = 0.109022 m
# [DEBUG] Παρατήρηση: el = 0.105851 m
# [DEBUG] Παρατήρηση: el = 0.098515 m
# [DEBUG] Παρατήρηση: el = 0.095398 m
# [DEBUG] Παρατήρηση: el = 0.194845 m
# [DEBUG] Παρατήρηση: el = 0.201485 m
# [DEBUG] Παρατήρηση: el = 0.204338 m
# [DEBUG] Παρατήρηση: el = 0.211010 m
# [DEBUG] Παρατήρηση: el = 0.213876 m
# [DEBUG] Παρατήρηση: el = 0.220576 m
# [DEBUG] Παρατήρηση: el = 0.223452 m
# [DEBUG] Παρατήρηση: el = 0.230175 m
# [DEBUG] Παρατήρηση: el = 0.233061 m
# [DEBUG] Παρατήρηση: el = 0.239802 m
# [DEBUG] Παρατήρηση: el = 0.242695 m
# [DEBUG] Παρατήρηση: el = 0.249448 m
# [DEBUG] Παρατήρηση: el = 0.252345 m
# [DEBUG] Παρατήρηση: el = 0.259104 m
# [DEBUG] Παρατήρηση: el = 0.262001 m
# [DEBUG] Παρατήρηση: el = 0.268760 m
# [DEBUG] Παρατήρηση: el = 0.271655 m
# [DEBUG] Παρατήρηση: el = 0.278404 m
# [DEBUG] Παρατήρηση: el = 0.281293 m
# [DEBUG] Παρατήρηση: el = 0.288023 m
# [DEBUG] Παρατήρηση: el = 0.290902 m
# [DEBUG] Παρατήρηση: el = 0.297604 m
# [DEBUG] Παρατήρηση: el = 0.300469 m
# [DEBUG] Παρατήρηση: el = 0.307132 m
# [DEBUG] Παρατήρηση: el = 0.309978 m
# [DEBUG] Παρατήρηση: el = 0.316590 m
# [DEBUG] Παρατήρηση: el = 0.319411 m
# [DEBUG] Παρατήρηση: el = 0.325959 m
# [DEBUG] Παρατήρηση: el = 0.328750 m
# [DEBUG] Παρατήρηση: el = 0.335221 m
# [DEBUG] Παρατήρηση: el = 0.337975 m
# [DEBUG] Παρατήρηση: el = 0.344353 m
# [DEBUG] Παρατήρηση: el = 0.347064 m
# [DEBUG] Παρατήρηση: el = 0.353333 m
# [DEBUG] Παρατήρηση: el = 0.355994 m
# [DEBUG] Παρατήρηση: el = 0.362138 m
# [DEBUG] Παρατήρηση: el = 0.364741 m
# [DEBUG] Παρατήρηση: el = 0.370740 m
# [DEBUG] Παρατήρηση: el = 0.373278 m
# [DEBUG] Παρατήρηση: el = 0.379115 m
# [DEBUG] Παρατήρηση: el = 0.381578 m
# [DEBUG] Παρατήρηση: el = 0.387232 m
# [DEBUG] Παρατήρηση: el = 0.389613 m
# [DEBUG] Παρατήρηση: el = 0.395063 m
# [DEBUG] Παρατήρηση: el = 0.397352 m
# [DEBUG] Παρατήρηση: el = 0.402579 m
# [DEBUG] Παρατήρηση: el = 0.404767 m
# [DEBUG] Παρατήρηση: el = 0.409747 m
# [DEBUG] Παρατήρηση: el = 0.411826 m
# [DEBUG] Παρατήρηση: el = 0.416538 m
# [DEBUG] Παρατήρηση: el = 0.418497 m
# [DEBUG] Παρατήρηση: el = 0.422920 m
# [DEBUG] Παρατήρηση: el = 0.424750 m
# [DEBUG] Παρατήρηση: el = 0.428862 m
# [DEBUG] Παρατήρηση: el = 0.430555 m
# [DEBUG] Παρατήρηση: el = 0.434335 m
# [DEBUG] Παρατήρηση: el = 0.435881 m
# [DEBUG] Παρατήρηση: el = 0.439309 m
# [DEBUG] Παρατήρηση: el = 0.440700 m
# [DEBUG] Παρατήρηση: el = 0.443758 m
# [DEBUG] Παρατήρηση: el = 0.444986 m
# [DEBUG] Παρατήρηση: el = 0.447655 m
# [DEBUG] Παρατήρηση: el = 0.448713 m
# [DEBUG] Παρατήρηση: el = 0.450978 m
# [DEBUG] Παρατήρηση: el = 0.451860 m
# [DEBUG] Παρατήρηση: el = 0.453708 m
# [DEBUG] Παρατήρηση: el = 0.454408 m
# [DEBUG] Παρατήρηση: el = 0.455826 m
# [DEBUG] Παρατήρηση: el = 0.456341 m
# [DEBUG] Παρατήρηση: el = 0.457320 m
# [DEBUG] Παρατήρηση: el = 0.457645 m
# [DEBUG] Παρατήρηση: el = 0.458181 m
# [DEBUG] Παρατήρηση: el = 0.458314 m
# [DEBUG] Παρατήρηση: el = 0.458402 m
# [DEBUG] Παρατήρηση: el = 0.458343 m
# [DEBUG] Παρατήρηση: el = 0.457981 m
# [DEBUG] Παρατήρηση: el = 0.457731 m
# [DEBUG] Παρατήρηση: el = 0.456923 m
# [DEBUG] Παρατήρηση: el = 0.456481 m
# [DEBUG] Παρατήρηση: el = 0.455232 m
# [DEBUG] Παρατήρηση: el = 0.454603 m
# [DEBUG] Παρατήρηση: el = 0.452920 m
# [DEBUG] Παρατήρηση: el = 0.452107 m
# [DEBUG] Παρατήρηση: el = 0.450001 m
# [DEBUG] Παρατήρηση: el = 0.449009 m
# [DEBUG] Παρατήρηση: el = 0.446492 m
# [DEBUG] Παρατήρηση: el = 0.445328 m
# [DEBUG] Παρατήρηση: el = 0.442415 m
# [DEBUG] Παρατήρηση: el = 0.441085 m
# [DEBUG] Παρατήρηση: el = 0.437793 m
# [DEBUG] Παρατήρηση: el = 0.436304 m
# [DEBUG] Παρατήρηση: el = 0.432652 m
# [DEBUG] Παρατήρηση: el = 0.431012 m
# [DEBUG] Παρατήρηση: el = 0.427019 m
# [DEBUG] Παρατήρηση: el = 0.425238 m
# [DEBUG] Παρατήρηση: el = 0.420925 m
# [DEBUG] Παρατήρηση: el = 0.419011 m
# [DEBUG] Παρατήρηση: el = 0.414398 m
# [DEBUG] Παρατήρηση: el = 0.412360 m
# [DEBUG] Παρατήρηση: el = 0.407471 m
# [DEBUG] Παρατήρηση: el = 0.405319 m
# [DEBUG] Παρατήρηση: el = 0.400173 m
# [DEBUG] Παρατήρηση: el = 0.397917 m
# [DEBUG] Παρατήρηση: el = 0.392537 m
# [DEBUG] Παρατήρηση: el = 0.390185 m
# [DEBUG] Παρατήρηση: el = 0.384594 m
# [DEBUG] Παρατήρηση: el = 0.382155 m
# [DEBUG] Παρατήρηση: el = 0.376372 m
# [DEBUG] Παρατήρηση: el = 0.373856 m
# [DEBUG] Παρατήρηση: el = 0.367901 m
# [DEBUG] Παρατήρηση: el = 0.365316 m
# [DEBUG] Παρατήρηση: el = 0.359210 m
# [DEBUG] Παρατήρηση: el = 0.356563 m
# [DEBUG] Παρατήρηση: el = 0.350324 m
# [DEBUG] Παρατήρηση: el = 0.347624 m
# [DEBUG] Παρατήρηση: el = 0.341270 m
# [DEBUG] Παρατήρηση: el = 0.338524 m
# [DEBUG] Παρατήρηση: el = 0.332070 m
# [DEBUG] Παρατήρηση: el = 0.329285 m
# [DEBUG] Παρατήρηση: el = 0.322748 m
# [DEBUG] Παρατήρηση: el = 0.319931 m
# [DEBUG] Παρατήρηση: el = 0.313324 m
# [DEBUG] Παρατήρηση: el = 0.310480 m
# [DEBUG] Παρατήρηση: el = 0.303818 m
# [DEBUG] Παρατήρηση: el = 0.300953 m
# [DEBUG] Παρατήρηση: el = 0.294248 m
# [DEBUG] Παρατήρηση: el = 0.291367 m
# [DEBUG] Παρατήρηση: el = 0.284629 m
# [DEBUG] Παρατήρηση: el = 0.281737 m
# [DEBUG] Παρατήρηση: el = 0.274978 m
# [DEBUG] Παρατήρηση: el = 0.272078 m
# [DEBUG] Παρατήρηση: el = 0.265307 m
# [DEBUG] Παρατήρηση: el = 0.262404 m
# [DEBUG] Παρατήρηση: el = 0.255629 m
# [DEBUG] Παρατήρηση: el = 0.252725 m
# [DEBUG] Παρατήρηση: el = 0.245954 m
# [DEBUG] Παρατήρηση: el = 0.243054 m
# [DEBUG] Παρατήρηση: el = 0.236294 m
# [DEBUG] Παρατήρηση: el = 0.233400 m
# [DEBUG] Παρατήρηση: el = 0.226657 m
# [DEBUG] Παρατήρηση: el = 0.223771 m
# [DEBUG] Παρατήρηση: el = 0.217050 m
# [DEBUG] Παρατήρηση: el = 0.214175 m
# [DEBUG] Παρατήρηση: el = 0.207481 m
# [DEBUG] Παρατήρηση: el = 0.204618 m
# [DEBUG] Παρατήρηση: el = 0.197955 m
# [DEBUG] Παρατήρηση: el = 0.195107 m
# [DEBUG] Παρατήρηση: el = 0.188479 m
# [DEBUG] Παρατήρηση: el = 0.185647 m
# [DEBUG] Παρατήρηση: el = 0.179057 m
# [DEBUG] Παρατήρηση: el = 0.176241 m
# [DEBUG] Παρατήρηση: el = 0.169692 m
# [DEBUG] Παρατήρηση: el = 0.166894 m

# %%
# Αρχική εκτίμηση beacon (π.χ. DIOB)
n_biases = 2
x0 = np.append(np.array(diob_xyz, dtype=float), np.zeros(n_biases))  # [x, y, z] σε ECEF

m = len(raw_obs)                      # αριθμός παρατηρήσεων
J = np.zeros((m, 5))                  # Ιακωβιανός πίνακας
dl = np.zeros(m)                      # διάνυσμα residuals

LS_ITERATIONS = 3                     # επαναλήψεις Least Squares

for ls_iteration in range(LS_ITERATIONS):
    for i, obs in enumerate(raw_obs):
        rsat1 = obs['rsat1']
        rsat2 = obs['rsat2']
        dt = obs['dt']
        v_obs = obs['v_obs']
        dT = obs['dT']
        r_beacon = x0[0:3]
        delta_f = x0[3]
        delta_T = x0[4]


        # υπολογισμός θεωρητικής ταχύτητας
        r1 = np.linalg.norm(rsat1 - r_beacon)
        r2 = np.linalg.norm(rsat2 - r_beacon)
        v_theo = (r2 - r1) / dt

        # residual
        dl[i] = v_obs - delta_f - delta_T - v_theo

        # παράγωγος του v_theo ως προς x, y, z beacon (γραμμή του Ιακωβιανού)
        J[i, 0:3] = (r_beacon - rsat2) / (r2 * dt) - (r_beacon - rsat1) / (r1 * dt)
        J[i, 3] = +1.0
        J[i, 4] = +1.0

    # least squares επίλυση
    dx, *_ = np.linalg.lstsq(J, dl, rcond=None)
    x0 += dx

    # a-posteriori σφάλμα μονάδας βάρους
    sigma = np.sqrt(np.sum(dl**2) / (m - 3))

    print(f"Iteration {ls_iteration+1}: Δx = ({dx[0]:+.3f}, {dx[1]:+.3f}, {dx[2]:+.3f}) | Δf = {dx[3]:+.6f} | σ = {sigma:.3f}")
    print(f"m = {m}, n = {J.shape[1]}")

# %% [markdown]
# Plot residuals

# %% [markdown]
# #for i in range(len(res2)):
# #    print(res1[i] - res2[i])
# print("len(t):", len(t))
# print("len(res1):", len(res1))

# %%
#plt.scatter([at2pt(ti) for ti in t], res2, alpha=0.5, s=12, c='blue')
plt.scatter([at2pt(ti) for ti in t], dl, alpha=0.5, s=12, c='red')
# plt.plot([at2pt(ti) for ti in t], res, alpha=0.3, linewidth=1)

plt.grid(color='0.95')
plt.ylabel(f"Residuals from L1 Range-Rate at {diob} in [m/sec]")
plt.title(f"Satellite {rnx.sat_name}")

# Format the datetime x-axis
ax = plt.gca()
ax.xaxis.set_major_formatter(mdates.DateFormatter("%d-%m-%y %H:%M:%S"))
# auto-rotate date labels for readability
plt.gcf().autofmt_xdate()

plt.show()

# %% [markdown]
# ## Correlation with Elevation

# %%
t1=None
els = []; res=[];
for block in rnx:
    for beacon, data in block:
        if beacon == diob:
            t2 = block.t() + attotime.attotimedelta(nanoseconds=block.clock_offset()*1e9)
            satx, saty, satz, _, _ = alg.sat_at_emission_time(diob_xyz, t2, intrp, None)
            L2 = data['L1']['value']
            r2 = np.linalg.norm(np.array([satx, saty, satz])-np.array(diob_xyz))
            _, _, el = azele(np.array((satx, saty, satz)), np.array(diob_xyz))
            if t1 is not None and (t2 - t1).total_seconds() <= 10.:
                crr = (r2 - r1) / (float((t2-t1).total_nanoseconds()) * 1e-9)
                orr = ((L2-L1) / (float((t2-t1).total_nanoseconds()) * 1e-9)) * (299792458./2036.25e6)
                if abs(orr - crr) > 100.:
                    pass
                else:
                    res.append(orr - crr)
                    els.append(np.degrees(el))
            r1 = r2
            t1 = t2
            L1 = L2

# %%
plt.scatter(els, res, alpha=0.3, marker='o')
plt.grid(color='0.95')
plt.ylabel(f"Residuals from L1 Range-Rate at {diob} in [m/sec]")
plt.xlabel("Elevation [deg]")
plt.title(f"Satellite {rnx.sat_name}")
plt.show()
